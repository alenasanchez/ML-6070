# %% [markdown]
# # Your name: Alena Sanchez
# ## Assignment Name: CA01 - Data Cleaning and Exploration of India Air Quality

# %% [markdown]
# # Program Inititialization Section
# ## Enter your import packages here

# %%
# import packages 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# !pip install -U scikit-learn

# %% [markdown]
# # Data File Reading Section
# ## Write code to read in data from external sources here

# %%
#read datasets
data = pd.read_csv('data.csv', encoding = "ISO-8859-1")

data.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   stn_code       sampling_date  ... pm2_5        date
# 0    150.0  February - M021990  ...   NaN  1990-02-01
# 1    151.0  February - M021990  ...   NaN  1990-02-01
# 2    152.0  February - M021990  ...   NaN  1990-02-01
# 3    150.0     March - M031990  ...   NaN  1990-03-01
# 4    151.0     March - M031990  ...   NaN  1990-03-01
# 5    152.0     March - M031990  ...   NaN  1990-03-01
# 6    150.0     April - M041990  ...   NaN  1990-04-01
# 7    151.0     April - M041990  ...   NaN  1990-04-01
# 8    152.0     April - M041990  ...   NaN  1990-04-01
# 9    151.0       May - M051990  ...   NaN  1990-05-01
#
# [10 rows x 13 columns]

# %% [markdown]
# # Initial Data Investigation Section
#
# ## Summarized details
# ### Generate descriptive statistics that summarize the central tendency, dispersion, and shape of a dataset’s distribution, excluding NaN values.
# #### Steps:
# #### 1. Statistical Description of data (data.describe)
# #### 2. Display number of total rows and columns of the dataset (data.shape)
# #### 3. Display number of non-null values for each column (data.count)
# #### 4. Display number of null values for each column (sum of data.isnull)
# #### 5. Display range, column, number of non-null objects of each column, datatype and memory usage (data.info)
# #### 6. Display Top 10 and Bottom 10 records (head and tail)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Your code for this section here ...

# %%
#1 Statistical Description of Data
data.describe()
# Out:
#                  so2            no2           rspm            spm        pm2_5
# count  401096.000000  419509.000000  395520.000000  198355.000000  9314.000000
# mean       10.829414      25.809623     108.832784     220.783480    40.791467
# std        11.177187      18.503086      74.872430     151.395457    30.832525
# min         0.000000       0.000000       0.000000       0.000000     3.000000
# 25%         5.000000      14.000000      56.000000     111.000000    24.000000
# 50%         8.000000      22.000000      90.000000     187.000000    32.000000
# 75%        13.700000      32.200000     142.000000     296.000000    46.000000
# max       909.000000     876.000000    6307.033333    3380.000000   504.000000

# %%
#2 Number of Total Rows and Columns of the Dataset
data.shape
# Out:
# (435742, 13)

# %%
#3 Number of Non-Null Values for each Column
data.count(axis = 0)
# Out:
# stn_code                       291665
# sampling_date                  435739
# state                          435742
# location                       435739
# agency                         286261
# type                           430349
# so2                            401096
# no2                            419509
# rspm                           395520
# spm                            198355
# location_monitoring_station    408251
# pm2_5                            9314
# date                           435735
# dtype: int64

# %%
#4 Number of Null Values for each Column
data.isnull().sum()
# Out:
# stn_code                       144077
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                             5393
# so2                             34646
# no2                             16233
# rspm                            40222
# spm                            237387
# location_monitoring_station     27491
# pm2_5                          426428
# date                                7
# dtype: int64

# %%
#5 Display range, column, number of non-null objects of each column, datatype and memory usage
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435742 entries, 0 to 435741
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   stn_code                     291665 non-null  object
#  1   sampling_date                435739 non-null  object
#  2   state                        435742 non-null  object
#  3   location                     435739 non-null  object
#  4   agency                       286261 non-null  object
#  5   type                         430349 non-null  object
#  6   so2                          401096 non-null  float64
#  7   no2                          419509 non-null  float64
#  8   rspm                         395520 non-null  float64
#  9   spm                          198355 non-null  float64
#  10  location_monitoring_station  408251 non-null  object
#  11  pm2_5                        9314 non-null    float64
# ...

# %%
#6 Display Top 10
data.head(10)
# Out:
#   stn_code       sampling_date  ... pm2_5        date
# 0    150.0  February - M021990  ...   NaN  1990-02-01
# 1    151.0  February - M021990  ...   NaN  1990-02-01
# 2    152.0  February - M021990  ...   NaN  1990-02-01
# 3    150.0     March - M031990  ...   NaN  1990-03-01
# 4    151.0     March - M031990  ...   NaN  1990-03-01
# 5    152.0     March - M031990  ...   NaN  1990-03-01
# 6    150.0     April - M041990  ...   NaN  1990-04-01
# 7    151.0     April - M041990  ...   NaN  1990-04-01
# 8    152.0     April - M041990  ...   NaN  1990-04-01
# 9    151.0       May - M051990  ...   NaN  1990-05-01
#
# [10 rows x 13 columns]

# %%
#6 Display Bottom 10
data.tail(10)
# Out:
#        stn_code sampling_date  ... pm2_5        date
# 435732     SAMP      09-12-15  ...   NaN  2015-12-09
# 435733     SAMP      12-12-15  ...   NaN  2015-12-12
# 435734     SAMP      15-12-15  ...   NaN  2015-12-15
# 435735     SAMP      18-12-15  ...   NaN  2015-12-18
# 435736     SAMP      21-12-15  ...   NaN  2015-12-21
# 435737     SAMP      24-12-15  ...   NaN  2015-12-24
# 435738     SAMP      29-12-15  ...   NaN  2015-12-29
# 435739      NaN           NaN  ...   NaN         NaN
# 435740      NaN           NaN  ...   NaN         NaN
# 435741      NaN           NaN  ...   NaN         NaN
#
# [10 rows x 13 columns]

# %% [markdown]
# ## Cleansing the dataset
# ### Dropping of less valued columns:
# 1. stn_code, agency, sampling_date, location_monitoring_agency do not add much value to the dataset in terms of information. Therefore, we can drop those columns.
#
# 2. Dropping rows where no date is available.

# %%
# Cleaning up the data

#dropping columns that aren't required

data = data.drop(['stn_code', 'agency', 'sampling_date', 'location_monitoring_station'], axis =1)

# dropping rows where no date is available (removed 7 records)

data = data.dropna(axis=0, subset=['date'])

# %%
# displaying final columns (data.columns)
data.head()
data.columns
# Out:
# Index(['state', 'location', 'type', 'so2', 'no2', 'rspm', 'spm', 'pm2_5',
#        'date'],
#       dtype='object')

# %% [markdown]
# ### Changing the types to uniform format:
#
# Notice that the ‘type’ column has values such as ‘Industrial Area’ and ‘Industrial Areas’ — both actually mean the same, so let’s remove such type of stuff and make it uniform. Replace the 'type' values with standard codes as follows:
#
# types = {
#     "Residential": "R",
#     "Residential and others": "RO",
#     "Residential, Rural and other Areas": "RRO",
#     "Industrial Area": "I",
#     "Industrial Areas": "I",
#     "Industrial": "I",
#     "Sensitive Area": "S",
#     "Sensitive Areas": "S",
#     "Sensitive": "S",
#     np.nan: "RRO"
# }
#
# data.type = data.type.replace(types)

# %%
# ... Your code here
types = { "Residential": "R", "Residential and others": "RO", "Residential, Rural and other Areas": "RRO", 
         "Industrial Area": "I", "Industrial Areas": "I", "Industrial": "I", "Sensitive Area": "S",
         "Sensitive Areas": "S", "Sensitive": "S", np.nan: "RRO" }

data.type = data.type.replace(types)

# %%
# Display top 10 records after codification of 'types'
data.head(10)
# Out:
#             state   location type  so2   no2  rspm  spm  pm2_5        date
# 0  Andhra Pradesh  Hyderabad  RRO  4.8  17.4   NaN  NaN    NaN  1990-02-01
# 1  Andhra Pradesh  Hyderabad    I  3.1   7.0   NaN  NaN    NaN  1990-02-01
# 2  Andhra Pradesh  Hyderabad  RRO  6.2  28.5   NaN  NaN    NaN  1990-02-01
# 3  Andhra Pradesh  Hyderabad  RRO  6.3  14.7   NaN  NaN    NaN  1990-03-01
# 4  Andhra Pradesh  Hyderabad    I  4.7   7.5   NaN  NaN    NaN  1990-03-01
# 5  Andhra Pradesh  Hyderabad  RRO  6.4  25.7   NaN  NaN    NaN  1990-03-01
# 6  Andhra Pradesh  Hyderabad  RRO  5.4  17.1   NaN  NaN    NaN  1990-04-01
# 7  Andhra Pradesh  Hyderabad    I  4.7   8.7   NaN  NaN    NaN  1990-04-01
# 8  Andhra Pradesh  Hyderabad  RRO  4.2  23.0   NaN  NaN    NaN  1990-04-01
# 9  Andhra Pradesh  Hyderabad    I  4.0   8.9   NaN  NaN    NaN  1990-05-01

# %% [markdown]
# ### Creating a year column
# To view the trend over a period of time, we need year values for each row and also when you see in most of the values in date column only has ‘year’ value. So, let’s create a new column holding year values. Convert the column to 'datetime' type and extract the year to populate the new column. Display Top 5 records after the conversion.

# %%
data.dtypes
data['date'] = pd.to_datetime(data['date'])
data.dtypes

data['year'] = pd.DatetimeIndex(data['date']).year
data.head(5)
# Out:
#             state   location type  so2   no2  rspm  spm  pm2_5       date  year
# 0  Andhra Pradesh  Hyderabad  RRO  4.8  17.4   NaN  NaN    NaN 1990-02-01  1990
# 1  Andhra Pradesh  Hyderabad    I  3.1   7.0   NaN  NaN    NaN 1990-02-01  1990
# 2  Andhra Pradesh  Hyderabad  RRO  6.2  28.5   NaN  NaN    NaN 1990-02-01  1990
# 3  Andhra Pradesh  Hyderabad  RRO  6.3  14.7   NaN  NaN    NaN 1990-03-01  1990
# 4  Andhra Pradesh  Hyderabad    I  4.7   7.5   NaN  NaN    NaN 1990-03-01  1990

# %% [markdown]
# ### Handling Missing Values
#
# The column such as SO2, NO2, rspm, spm, pm2_5 are the ones which contribute much to our analysis. So, we need to remove null from those columns to avoid inaccuracy in the prediction.
# We use the Imputer from sklearn.preprocessing to fill the missing values in every column with the mean.

# %%
# define columns of importance, which shall be used reguarly (COLS = ....)

#COLS = ['so2', 'no2', 'rspm', 'spm', 'pm2_5']

COLS = data.loc[:,['so2', 'no2', 'rspm', 'spm', 'pm2_5']]

# invoke SimpleImputer to fill missing values using 'mean' as the replacement strategy
def impute_mean(fill_mean):
    return fill_mean.fillna(fill_mean.mean())

COLS = COLS.transform(impute_mean)

imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
imputer = imputer.fit(COLS.values)
COLS = imputer.transform(COLS.values)


data.info()
data.isnull().sum()
data.head(5)

# %% [markdown]
# ## Statewise Grouping of so2, no2, rspm, spm values
#
# Calculate median values of so2, no2, rspm, spm for each state and display in (a) as table (b) bar chart, with values sorted in ascending order. Separate section for each of the component. Use matplotlib().

# %% [markdown]
# ### so2 status

# %%
so2_median = data.groupby('state', as_index=False)['so2'].median()
so2_median
sorted_so2 = so2_median.sort_values(by='so2')
sorted_so2
# Out:
#                    state        so2
# 22              Nagaland   2.000000
# 21               Mizoram   2.000000
# 20             Meghalaya   2.000000
# 1      Arunachal Pradesh   2.500000
# 12      Himachal Pradesh   3.000000
# 16                Kerala   4.200000
# 29             Telangana   5.000000
# 23                Odisha   5.000000
# 13       Jammu & Kashmir   5.000000
# 0         Andhra Pradesh   5.000000
# 9                    Goa   6.000000
# 26             Rajasthan   6.300000
# 8                  Delhi   6.300000
# 2                  Assam   6.500000
# 24            Puducherry   7.266667
# 7            Daman & Diu   7.600000
# 4             Chandigarh   7.950000
# 33           West Bengal   8.000000
# 6   Dadra & Nagar Haveli   8.400000
# 15             Karnataka  10.000000
# 30         Uttar Pradesh  10.000000
# 28            Tamil Nadu  10.000000
# 25                Punjab  10.300000
# 19               Manipur  10.829428
# 3                  Bihar  10.829428
# ...

# %%
plt.bar(sorted_so2.state, sorted_so2.so2, color = "lightblue")
plt.xticks(rotation=90)
plt.show()

# %%
#Uttaranchal has the highest so2
#Nagaland has the lowest so2

# %% [markdown]
# ### no2 status

# %%
no2_median = data.groupby('state', as_index=False)['no2'].median()
no2_median
sorted_no2 = no2_median.sort_values(by='no2')
sorted_no2
# Out:
#                    state        no2
# 1      Arunachal Pradesh   5.000000
# 21               Mizoram   5.000000
# 22              Nagaland   7.000000
# 20             Meghalaya  10.000000
# 9                    Goa  11.600000
# 24            Puducherry  13.000000
# 13       Jammu & Kashmir  13.000000
# 12      Himachal Pradesh  13.900000
# 16                Kerala  14.000000
# 2                  Assam  14.000000
# 23                Odisha  16.000000
# 7            Daman & Diu  17.600000
# 4             Chandigarh  18.000000
# 6   Dadra & Nagar Haveli  18.000000
# 17        Madhya Pradesh  19.200000
# 19               Manipur  19.800000
# 0         Andhra Pradesh  20.000000
# 28            Tamil Nadu  21.000000
# 15             Karnataka  21.200000
# 5           Chhattisgarh  21.500000
# 29             Telangana  22.000000
# 11               Haryana  22.750000
# 10               Gujarat  23.000000
# 31           Uttarakhand  25.809659
# 26             Rajasthan  26.000000
# ...

# %%
plt.bar(sorted_no2.state, sorted_no2.no2, color = "lightblue")
plt.xticks(rotation=90)
plt.show()

# %%
#West Bengal has the highest no2
#Arunachal Pradesh has the lowest no2

# %% [markdown]
# ### rspm status

# %%
rspm_median = data.groupby('state', as_index=False)['rspm'].median()
rspm_median
sorted_rspm = rspm_median.sort_values(by='rspm')
sorted_rspm
# Out:
#                    state        rspm
# 27                Sikkim   32.000000
# 21               Mizoram   40.000000
# 24            Puducherry   46.000000
# 16                Kerala   49.000000
# 9                    Goa   56.000000
# 20             Meghalaya   57.000000
# 28            Tamil Nadu   59.000000
# 19               Manipur   61.000000
# 15             Karnataka   63.000000
# 1      Arunachal Pradesh   74.500000
# 0         Andhra Pradesh   76.000000
# 2                  Assam   77.000000
# 22              Nagaland   78.000000
# 29             Telangana   80.000000
# 23                Odisha   81.000000
# 12      Himachal Pradesh   90.000000
# 4             Chandigarh   90.000000
# 6   Dadra & Nagar Haveli   91.000000
# 10               Gujarat   95.000000
# 33           West Bengal   96.000000
# 18           Maharashtra   96.000000
# 5           Chhattisgarh  108.833091
# 17        Madhya Pradesh  108.833091
# 3                  Bihar  108.833091
# ...

# %%
plt.bar(sorted_rspm.state, sorted_rspm.rspm, color = "lightblue")
plt.xticks(rotation=90)
plt.show()

# %%
#Jharkhand has the highest rspm
#Sikkim has the lowest rspm

# %% [markdown]
# ### spm status

# %%
spm_median = data.groupby('state', as_index=False)['spm'].median()
spm_median
sorted_spm = spm_median.sort_values(by='spm')
sorted_spm
# Out:
#                    state        spm
# 27                Sikkim   75.00000
# 19               Manipur  120.50000
# 24            Puducherry  191.00000
# 9                    Goa  199.00000
# 7            Daman & Diu  200.50000
# 0         Andhra Pradesh  220.78348
# 20             Meghalaya  220.78348
# 21               Mizoram  220.78348
# 22              Nagaland  220.78348
# 23                Odisha  220.78348
# 25                Punjab  220.78348
# 28            Tamil Nadu  220.78348
# 29             Telangana  220.78348
# 30         Uttar Pradesh  220.78348
# 31           Uttarakhand  220.78348
# 26             Rajasthan  220.78348
# 18           Maharashtra  220.78348
# 16                Kerala  220.78348
# 15             Karnataka  220.78348
# 14             Jharkhand  220.78348
# 13       Jammu & Kashmir  220.78348
# 12      Himachal Pradesh  220.78348
# 11               Haryana  220.78348
# 10               Gujarat  220.78348
# 6   Dadra & Nagar Haveli  220.78348
# ...

# %%
plt.bar(sorted_spm.state, sorted_spm.spm, color = "lightblue")
plt.xticks(rotation=90)
plt.show()

# %%
#Uttaranchal has the highest spm
#Sikkim has the lowest spm

# %% [markdown]
# ### What is the yearly trend in a particular state, say ‘Andhra Pradesh’?
#
# Create a new dataframe containing the NO2, SO2, rspm, and spm data regarding state ‘Andhra Pradesh’ only and group it by ‘year’. Display top 5 records after.

# %%
new = data[data.state == 'Andhra Pradesh']
new = new.drop(['location',	'type',  'pm2_5', 'date'], axis = 1)
new
# Out:
#                 state  so2   no2        rspm        spm  year
# 0      Andhra Pradesh  4.8  17.4  108.833091  220.78348  1990
# 1      Andhra Pradesh  3.1   7.0  108.833091  220.78348  1990
# 2      Andhra Pradesh  6.2  28.5  108.833091  220.78348  1990
# 3      Andhra Pradesh  6.3  14.7  108.833091  220.78348  1990
# 4      Andhra Pradesh  4.7   7.5  108.833091  220.78348  1990
# ...               ...  ...   ...         ...        ...   ...
# 26363  Andhra Pradesh  7.0  13.0   71.000000  220.78348  2015
# 26364  Andhra Pradesh  7.0  18.0   77.000000  220.78348  2015
# 26365  Andhra Pradesh  8.0  23.0   64.000000  220.78348  2015
# 26366  Andhra Pradesh  7.0  19.0   61.000000  220.78348  2015
# 26367  Andhra Pradesh  6.0  17.0   71.000000  220.78348  2015
#
# [26368 rows x 6 columns]

# %%
new = data.groupby('year', as_index=False)['so2','no2', 'rspm', 'spm'].mean()
new.head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#    year        so2        no2        rspm         spm
# 0  1987  18.897791  29.491230  108.833091  278.401290
# 1  1988  20.094001  29.760829  108.833091  247.353570
# 2  1989  18.315661  29.133042  108.833091  237.620273
# 3  1990  17.467824  25.716276  108.833091  242.305362
# 4  1991  17.175638  25.979131  108.833091  241.396689

# %%
# Display yearly trend graph (year vs. value) in pairs: (a) so2 and no2 (b) rspm and spm. 
# So, you will display TWO graphs altogether.
so2 = plt.plot(new.year, new.so2, color = 'lightblue', marker = 'o')
no2 = plt.plot(new.year, new.no2, color = 'red', marker = 'o')
plt.legend((['so2','no2']))
plt.show()

# %%
plt.plot(new.year, new.rspm, color = 'lightblue', marker = 'o')
plt.plot(new.year, new.spm, color = 'red', marker = 'o')
plt.legend((['rspm','spm']))
plt.show()

# %% [markdown]
# Do you find anythumg alarming? Explain what you can conclude from this Exploratory Data Analysis for the State of Andhra Pradesh. Enter your answer here .....

# %%
'''
After running the exploratory analysis on the India Air Quality Data we can see that the various states have different median levels
of the various parameters that measure air quality, but we can see that those states that tend to have low levels of spm seem 
to also have low levels of the rspm and vice versa. For example, we can see that Sikkim has the lowest levels of both spm and rspm, 
but Sikkim does not have relatively low levels of no2 or so2. Additionally, we see that Nagaland has low levels of both no2 and so2 meaning 
that the parameters most likely correlate in pairs; no2 and so2 & rspm and spm. Furthermore, we can see that Andhra Pradesh is a state that is generally
in the middle of all parameters compared to all the states. Specific to the state, so2 is lower than no2 and rspm is lower than spm! Overall, states like Delhi
and West Bengal seem to have high levels of all parameters, so action for cleaner air should be implemented in those areas
first as they are in a more urgent need for it.

'''
